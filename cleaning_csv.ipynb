# %% [markdown]
# # Code to clean and process titles
#
# Some preprocessing is needed to increase the preformance of the model.
# ie removing stop words and words which are not necessarily important for senimtent analysis.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
# Out:
# C:\Users\moazz\AppData\Local\Temp\ipykernel_16564\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('cleaned_headlines.csv')

# %%
data.shape
# Out:
# (3500, 24)

# %%
test_data = data[0:500]

# %%
test_data.head()
# Out:
#                                                title  \
# 0  Iran uses Artificial Intelligence for maximizi...
# 1  Mortgage Lenders See AI As Key To Operational ...
# 2  How the Threat of AI Coincided with the Writer...
# 3  Telex : Le code source du ransomware HelloKitt...
# 4                Is AI a Master or Slave? - Namibian
#
#                                                 link        date  \
# 0  https://news.google.com/rss/articles/CBMigAFod...  2023-05-07
# 1  https://news.google.com/rss/articles/CBMiYGh0d...  2023-10-09
# 2  https://news.google.com/rss/articles/CBMiX2h0d...  2023-10-04
# 3  https://news.google.com/rss/articles/CBMiwgFod...  2023-10-09
# 4  https://news.google.com/rss/articles/CBMiNGh0d...  2023-10-03
#
#                            source country language  Manual Sentiment  \
# 0                        ANI News      US       en              -1.0
# 1  National Mortgage Professional      US       en               1.0
# 2                   The Spectator      US       en              -1.0
# 3           Le Monde Informatique      US       fr               0.0
# 4                        Namibian      US       en              -1.0
#
#                                     translated_title  \
# 0  Iran uses Artificial Intelligence for maximizi...
# 1  Mortgage Lenders See AI As Key To Operational ...
# 2  How the Threat of AI Coincided with the Writer...
# 3  Telex: HelloKitty ransomware source code revea...
# 4                Is AI a Master or Slave? - Namibian
#
#    number_of_characters_title  number_of_words_title  ... is_weekend  \
# 0                          70                     11  ...       True
# 1                          77                     13  ...      False
# 2                          59                     13  ...      False
# 3                         129                     22  ...      False
# 4                          28                      8  ...      False
#
#    is_holiday            source_type  \
# 0       False            News Outlet
# 1        True  Press Release Service
# 2       False            News Outlet
# 3        True                  Other
# 4       False                  Other
#
#                                 final_redirected_URL  \
# 0  https://www.aninews.in/news/world/middle-east/...
# 1  https://nationalmortgageprofessional.com/news/...
# 2  https://seattlespectator.com/2023/10/04/how-th...
# 3  https://www.lemondeinformatique.fr/actualites/...
# 4  https://www.namibian.com.na/is-ai-a-master-or-...
#
#                       domain_of_URL              subdomain_of_URL URL_depth  \
# 0                    www.aninews.in                           www         4
# 1  nationalmortgageprofessional.com  nationalmortgageprofessional         2
# 2              seattlespectator.com              seattlespectator         5
# 3        www.lemondeinformatique.fr                           www         2
# 4               www.namibian.com.na                           www         2
#
#   top_level_domain url_length  \
# 0               in        128
# 1              com         96
# 2              com         95
# 3               fr        194
# 4               na         52
#
#                                               author
# 0                                                 []
# 1                               ['Christine Stuart']
# 2            ['Hannah Mwangi', 'Volunteer Reporter']
# 3                                                 []
# 4  ['Joschka Fischer', 'Please Enter Your Name He...
#
# [5 rows x 24 columns]

# %%
nans_df =test_data[test_data['Manual Sentiment'].isna()]
nans_df
# Out:
# Empty DataFrame
# Columns: [title, link, date, source, country, language, Manual Sentiment, translated_title, number_of_characters_title, number_of_words_title, day_of_week, month, year, quarter, is_weekend, is_holiday, source_type, final_redirected_URL, domain_of_URL, subdomain_of_URL, URL_depth, top_level_domain, url_length, author]
# Index: []
#
# [0 rows x 24 columns]

# %%
data.loc[228, 'Manual Sentiment'] = -1

# %%
nans_df =test_data[test_data['Manual Sentiment'].isna()]
nans_df
# Out:
# Empty DataFrame
# Columns: [title, link, date, source, country, language, Manual Sentiment, translated_title, number_of_characters_title, number_of_words_title, day_of_week, month, year, quarter, is_weekend, is_holiday, source_type, final_redirected_URL, domain_of_URL, subdomain_of_URL, URL_depth, top_level_domain, url_length, author]
# Index: []
#
# [0 rows x 24 columns]

# %%
data.to_csv('cleaned_headlines.csv', index=False)

# %% [markdown]
# ## Cleaning Source from Headlines

# %%
import pandas as pd
data = pd.read_csv('data/Dataset_10k.csv')
# Out:
# /tmp/ipykernel_5052/2062707627.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data
# Out:
#                                                   title  \
# 0     Kann künstliche Intelligenz Smalltalk ersetzen...
# 1     Lidé se snadněji svěří chatbotům. Emocionální ...
# 2     ¿Cómo implementar la IA en el comercio online?...
# 3     Kontrolle von KI: Vorsicht, KI! | ZEIT ONLINE ...
# 4     Los consejos para ganar la lotería de la Intel...
# ...                                                 ...
# 9995  Charlie Munger on AI: 'I think old-fashioned i...
# 9996  I went on patrol with AI police robot that wil...
# 9997  EVA.ai kondigt nieuwe AI-sidekick aan met 6 mi...
# 9998                從AI到LLM：建置有序的人工智慧模型作業流程 - DIGITIMES
# 9999  Alexa Evolves with Advanced AI Technology: Ama...
#
#                                                    link        date  \
# 0     https://news.google.com/rss/articles/CBMiY2h0d...  2023-11-12
# 1     https://news.google.com/rss/articles/CBMidmh0d...  2023-11-12
# 2     https://news.google.com/rss/articles/CBMicmh0d...  2023-11-12
# 3     https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
# 4     https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
# ...                                                 ...         ...
# 9995  https://news.google.com/rss/articles/CBMid2h0d...  2023-05-06
# 9996  https://news.google.com/rss/articles/CBMiVWh0d...  2023-05-05
# 9997  https://news.google.com/rss/articles/CBMicWh0d...  2023-05-05
# 9998  https://news.google.com/rss/articles/CBMiVWh0d...  2023-05-05
# 9999  https://news.google.com/rss/articles/CBMiR2h0d...  2023-05-05
#
#                    source country language  \
# 0                   Blick      US       de
# 1                iDNES.cz      US       cs
# 2            RRHH Digital      US       es
# 3     ZEIT ONLINE English      US       de
# 4                     C5N      US       es
# ...                   ...     ...      ...
# 9995        Yahoo Finance      US       en
# 9996              The Sun      US       en
# 9997   Recruitmenttech.nl      US       nl
# 9998            DIGITIMES      US       ko
# 9999           gizmochina      US       en
#
#                                        translated_title  \
# 0     Can artificial intelligence replace small talk...
# 1     People trust chatbots more easily. Emotional A...
# 2     How to implement AI in online commerce? - Digi...
# 3     Controlling AI: Be careful, AI! | ZEIT ONLINE ...
# 4     Tips to win the Artificial Intelligence lotter...
# ...                                                 ...
# 9995  Charlie Munger on AI: 'I think old-fashioned i...
# 9996  I went on patrol with AI police robot that wil...
# 9997  EVA.ai announces new AI sidekick with 6 billio...
# 9998  From AI to LLM: Establishing an orderly artifi...
# 9999  Alexa Evolves with Advanced AI Technology: Ama...
#
#       number_of_characters_title  number_of_words_title day_of_week  ...  \
# 0                             47                      8      Sunday  ...
# 1                             72                     13      Sunday  ...
# 2                             43                     10      Sunday  ...
# 3                             56                     12      Sunday  ...
# 4                             45                      9      Sunday  ...
# ...                          ...                    ...         ...  ...
# 9995                          79                     14    Saturday  ...
# 9996                          91                     25      Friday  ...
# 9997                          72                     12      Friday  ...
# 9998                          78                     13      Friday  ...
# 9999                          67                     12      Friday  ...
#
#       is_weekend  is_holiday  source_type  \
# 0           True       False  News Outlet
# 1           True       False        Other
# 2           True       False  News Outlet
# 3           True       False        Other
# 4           True       False        Other
# ...          ...         ...          ...
# 9995        True       False  News Outlet
# 9996       False       False  News Outlet
# 9997       False       False         Blog
# 9998       False       False  News Outlet
# 9999       False       False        Other
#
#                                    final_redirected_URL  \
# 0     https://www.blick.ch/schweiz/linguistik-profes...
# 1     https://www.idnes.cz/zpravy/domaci/ai-umela-in...
# 2     https://www.rrhhdigital.com/secciones/tecnolog...
# 3     https://www.zeit.de/zeit-wissen/2023/06/kuenst...
# 4     https://www.c5n.com/sociedad/los-consejos-gana...
# ...                                                 ...
# 9995  https://finance.yahoo.com/news/charlie-munger-...
# 9996  https://www.thesun.co.uk/tech/22266675/patrol-...
# 9997  https://www.recruitmenttech.nl/2023/05/05/eva-...
# 9998  https://www.digitimes.com.tw/tech/dt/n/shwnws....
# 9999  https://www.gizmochina.com/2023/05/05/amazon-a...
#
#                domain_of_URL subdomain_of_URL URL_depth top_level_domain  \
# 0               www.blick.ch              www         2               ch
# 1               www.idnes.cz              www         3               cz
# 2        www.rrhhdigital.com              www         5              com
# 3                www.zeit.de              www         4               de
# 4                www.c5n.com              www         2              com
# ...                      ...              ...       ...              ...
# 9995       finance.yahoo.com          finance         2              com
# 9996        www.thesun.co.uk              www         4               uk
# 9997  www.recruitmenttech.nl              www         5               nl
# 9998    www.digitimes.com.tw              www         4               tw
# 9999      www.gizmochina.com              www         5              com
#
#      url_length                                             author
# 0            99                                                 []
# 1           118                                          ['Autor']
# 2           114                                                 []
# 3            93                                                 []
# 4            93                                                 []
# ...         ...                                                ...
# 9995        119                                                 []
# 9996         85                                  ['Oliver Harvey']
# 9997        113                                                 []
# 9998         85                                                 []
# 9999         71  ['As A Technology Enthusiast', 'I Have Been Pr...
#
# [10000 rows x 23 columns]

# %%
news_headline = "Iran uses Artificial Intelligence for maximizing suppression: Experts - ANI News"
def strip_source(news_headline):
    # Reverse the string
    reversed_headline = news_headline[::-1]
    
    # Find the index of the first dash in the reversed string
    index_of_dash = reversed_headline.find('-')
    
    if index_of_dash != -1:
        # Remove everything up to the first dash
        modified_headline = reversed_headline[index_of_dash+1:].strip()
    else:
        # If dash not found, return the original reversed headline
        modified_headline = reversed_headline
    
    # Reverse the modified string back to the original order
    modified_headline = modified_headline[::-1]

    return modified_headline

# %%
data['cleaned_title'] = data['translated_title'].apply(strip_source)

# %%
data['translated_title'].head()
# Out:
# 0    Can artificial intelligence replace small talk...
# 1    People trust chatbots more easily. Emotional A...
# 2    How to implement AI in online commerce? - Digi...
# 3    Controlling AI: Be careful, AI! | ZEIT ONLINE ...
# 4    Tips to win the Artificial Intelligence lotter...
# Name: translated_title, dtype: object

# %%
data.to_csv('./data/clean_titles.csv', index = False)
