# %% [markdown]
# # Emotional Analysis

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
data = pd.read_csv('emotions_data.csv')
data.head()
import numpy as np
# Apply regular expression to extract words from 'emotions' column
for i in range(len(data)):
    data.at[i, 'emotions'] = re.findall('\w+', data.at[i, 'emotions'])

data['emotion_scores'] = data['emotion_scores'].apply(lambda x: list(map(float, re.findall(r'\d+\.\d+', x))) if pd.notnull(x) else [])

# %% [markdown]
# # Average Emotion Score per Headline

# %%
dictionary = {'Concern': 0, 'Skepticism': 0, 'Excitement': 0, 'Optimism': 0}

# Assuming 'data' is your DataFrame containing emotions and scores
for k in range(len(data)):
    for i in range(4):
        if data.iloc[k]['emotions'][i] == 'Concern':
            dictionary['Concern'] += data.iloc[k]['emotion_scores'][i]
        if data.iloc[k]['emotions'][i] == 'Skepticism':
            dictionary['Skepticism'] += data.iloc[k]['emotion_scores'][i]
        if data.iloc[k]['emotions'][i] == 'Excitement':
            dictionary['Excitement'] += data.iloc[k]['emotion_scores'][i]
        if data.iloc[k]['emotions'][i] == 'Optimism':
            dictionary['Optimism'] += data.iloc[k]['emotion_scores'][i]

values = list(map(lambda x: x / 10000, list(dictionary.values())))
keys = list(dictionary.keys())

sorted_data = sorted(zip(keys, values), key=lambda x: x[1], reverse=True)
sorted_keys, sorted_values = zip(*sorted_data)

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

theta = np.linspace(0, 2 * np.pi, len(sorted_keys), endpoint=False).tolist()
width = np.pi / (len(sorted_keys) + 2)  # Increase the denominator for narrower bars

bars = ax.bar(theta, sorted_values, width=width, bottom=0.0, color=plt.cm.viridis(sorted_values))

ax.set_theta_zero_location('N')  
ax.set_theta_direction(-1)  

ax.set_xticks(theta)
ax.set_xticklabels(sorted_keys)

max_bar_height = max(sorted_values)
ax.set_ylim(0, max_bar_height + 0.05)  # Adjust the padding to reduce white space

ax.set_title('Average Emotion Score Per Headline', va='bottom')
ax.yaxis.set_visible(False)  # Hide radial axis

for i, (bar, value) in enumerate(zip(bars, sorted_values)):
    theta_mid = theta[i] + width / 2.0
    ax.text(theta_mid, bar.get_height() + 0.03, f'{value:.2%}', ha='center', va='bottom')

plt.show()

# %%
num = np.random.randint(10000)
emotion = data.iloc[num].emotions
scores = data.iloc[num].emotion_scores
random_colors = np.random.rand(len(emotion), 3)
plt.pie(scores, labels=emotion, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title(data.iloc[num]['cleaned_title'])
plt.show()

# %%
num = np.random.randint(10000)
emotion = data.iloc[num].emotions
scores = data.iloc[num].emotion_scores
random_colors = np.random.rand(len(emotion), 3)
plt.pie(scores, labels=emotion, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title(data.iloc[num]['cleaned_title'])
plt.show()

# %%
conDictionary = {5:0,6:0,7:0,8:0,9:0,10:0,11:0}
skeptDictionary = {5:0,6:0,7:0,8:0,9:0,10:0,11:0}
optDictionary = {5:0,6:0,7:0,8:0,9:0,10:0,11:0}
ExDictionary = {5:0,6:0,7:0,8:0,9:0,10:0,11:0}
mayCount = 0
juneCount = 0
julyCount = 0
augCount = 0
sepCount = 0
octCount = 0
novCount = 0
for k in range(len(data)):
    for i in range(4):
        if data.iloc[k]['month'] == 5:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[5] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[5] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[5] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[5] += data.iloc[k]['emotion_scores'][i]
            mayCount += 1
        if data.iloc[k]['month'] == 6:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[6] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[6] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[6] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[6] += data.iloc[k]['emotion_scores'][i]
            juneCount += 1
        if data.iloc[k]['month'] == 7:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[7] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[7] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[7] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[7] += data.iloc[k]['emotion_scores'][i]
            julyCount += 1
        if data.iloc[k]['month'] == 8:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[8] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[8] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[8] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[8] += data.iloc[k]['emotion_scores'][i]
            augCount += 1
        if data.iloc[k]['month'] == 9:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[9] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[9] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[9] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[9] += data.iloc[k]['emotion_scores'][i]
            sepCount += 1
        if data.iloc[k]['month'] == 10:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[10] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[10] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[10] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[10] += data.iloc[k]['emotion_scores'][i]
            octCount += 1
        if data.iloc[k]['month'] == 11:        
            if data.iloc[k]['emotions'][i] == 'Skepticism':
                skeptDictionary[11] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Excitement':
                ExDictionary[11] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Optimism':
                optDictionary[11] += data.iloc[k]['emotion_scores'][i]
            if data.iloc[k]['emotions'][i] == 'Concern':
                conDictionary[11] += data.iloc[k]['emotion_scores'][i]
            novCount += 1

# %%
list_of_dicts = [conDictionary, ExDictionary, skeptDictionary, optDictionary]

maySum = sum([i[5] for i in list_of_dicts])
juneSum = sum([i[6] for i in list_of_dicts])
julySum = sum([i[7] for i in list_of_dicts])
augSum = sum([i[8] for i in list_of_dicts])
sepSum = sum([i[9] for i in list_of_dicts])
octSum = sum([i[10] for i in list_of_dicts])
novSum = sum([i[11] for i in list_of_dicts])

sums = [maySum, juneSum, julySum, augSum, sepSum, octSum, novSum]

keys = sorted(set(key for d in list_of_dicts for key in d.keys()))
values = [[d.get(key, 0) for key in keys] for d in list_of_dicts]

values_percentage = np.array(values) / np.sum(values, axis=0) * 100

colors = np.random.rand(len(list_of_dicts), 3)

fig, ax = plt.subplots()
bottom = np.zeros(len(keys))
names = ['Concern', 'Excitement', 'Skepticism', 'Optimism']

for i, dataset_values in enumerate(values_percentage):
    ax.bar(keys, dataset_values, bottom=bottom, label=names[i], color=colors[i])
    bottom += dataset_values

plt.xlabel('Month')
plt.ylabel('Values (%)')
plt.title('Monthly Distribution of Emotion Scores')

plt.xticks(keys, ['May', 'June', 'July', 'August', 'September', 'October', 'November'],rotation = 45)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame containing the 'date' column

# Get the top 20 dates by count
last_10_dates = data['date'].value_counts().head(5)

# Sort dates by count in descending order
last_10_dates_sorted = last_10_dates.sort_values(ascending=False)  # Sort in ascending order

# Reverse the sorted order to arrange in descending order
last_10_dates_sorted = last_10_dates_sorted[::-1]

# Use Seaborn's color palette to generate random colors
random_colors = sns.color_palette('viridis', len(last_10_dates_sorted))

# Create a horizontal bar plot
plt.figure(figsize=(10, 8))  # Adjust figure size as needed
plt.barh(last_10_dates_sorted.index, last_10_dates_sorted.values, color=random_colors)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Date')
plt.title('Headlines By Date')

# Show the plot
plt.show()

# %%
data['country'].hist(histtype='bar', edgecolor='black',bins=3)

# Add labels and title as needed
plt.xlabel('Country')
plt.ylabel('Count')
plt.grid(False)
plt.title('Headlines per Country')
plt.show()

# %%
corporate = data[data['source_type'] == 'Corporate']

# %%
academic = data[data['source_type'] == 'Academic Journal']

# %%
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(emotion), 3)
for i in range(len(corporate)):
    for k in range(4):
        if corporate.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += corporate.iloc[i]['emotion_scores'][k]
        if corporate.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += corporate.iloc[i]['emotion_scores'][k]
        if corporate.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += corporate.iloc[i]['emotion_scores'][k]
        if corporate.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += corporate.iloc[i]['emotion_scores'][k]
corpList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(corpList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Corporate Emotion Distribution')
plt.show()

# %%
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(emotion), 3)
for i in range(len(academic)):
    for k in range(4):
        if academic.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += academic.iloc[i]['emotion_scores'][k]
        if academic.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += academic.iloc[i]['emotion_scores'][k]
        if academic.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += academic.iloc[i]['emotion_scores'][k]
        if academic.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += academic.iloc[i]['emotion_scores'][k]
academicList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(academicList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Academic Journal Emotion Distribution')
plt.show()

# %%
blog = data[data['source_type'] == 'Blog']
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(emotion), 3)
for i in range(len(blog)):
    for k in range(4):
        if blog.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += blog.iloc[i]['emotion_scores'][k]
        if blog.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += blog.iloc[i]['emotion_scores'][k]
        if blog.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += blog.iloc[i]['emotion_scores'][k]
        if blog.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += blog.iloc[i]['emotion_scores'][k]
blogList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(blogList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Blog Emotion Distribution')
plt.show()

# %%
news = data[data['source_type'] == 'News Outlet']
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(emotion), 3)
for i in range(len(news)):
    for k in range(4):
        if news.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += news.iloc[i]['emotion_scores'][k]
        if news.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += news.iloc[i]['emotion_scores'][k]
        if news.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += news.iloc[i]['emotion_scores'][k]
        if news.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += news.iloc[i]['emotion_scores'][k]
blogList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(blogList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('News Emotion Distribution')
plt.show()

# %%
# Out:
#                                                         title  \
# 0        0  Kann künstliche Intelligenz Smalltalk ersetzen...
# 1        1  Lidé se snadněji svěří chatbotům. Emocionální ...
# 2        2  ¿Cómo implementar la IA en el comercio online?...
# 3        3  Kontrolle von KI: Vorsicht, KI! | ZEIT ONLINE ...
# 4        4  Los consejos para ganar la lotería de la Intel...
# ...    ...                                                ...
# 9995  9995  Charlie Munger on AI: 'I think old-fashioned i...
# 9996  9996  I went on patrol with AI police robot that wil...
# 9997  9997  EVA.ai kondigt nieuwe AI-sidekick aan met 6 mi...
# 9998  9998                從AI到LLM：建置有序的人工智慧模型作業流程 - DIGITIMES
# 9999  9999  Alexa Evolves with Advanced AI Technology: Ama...
#
#                                                    link        date  \
# 0     https://news.google.com/rss/articles/CBMiY2h0d...  2023-11-12
# 1     https://news.google.com/rss/articles/CBMidmh0d...  2023-11-12
# ...

# %%
isWeekend = data[data['is_weekend'] == True]
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(isWeekend), 3)
for i in range(len(isWeekend)):
    for k in range(4):
        if isWeekend.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += isWeekend.iloc[i]['emotion_scores'][k]
        if isWeekend.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += isWeekend.iloc[i]['emotion_scores'][k]
        if isWeekend.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += isWeekend.iloc[i]['emotion_scores'][k]
        if isWeekend.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += isWeekend.iloc[i]['emotion_scores'][k]
academicList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(academicList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Holiday Emotion Distribution')
plt.show()

# %%
nonWeekend = data[data['is_weekend'] == False]
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(nonWeekend), 3)
for i in range(len(nonWeekend)):
    for k in range(4):
        if nonWeekend.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += nonWeekend.iloc[i]['emotion_scores'][k]
        if nonWeekend.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += nonWeekend.iloc[i]['emotion_scores'][k]
        if nonWeekend.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += nonWeekend.iloc[i]['emotion_scores'][k]
        if nonWeekend.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += nonWeekend.iloc[i]['emotion_scores'][k]
academicList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(academicList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Non-Holiday Emotion Distribution')
plt.show()

# %%
isHoliday = data[data['is_holiday'] == True]
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(isHoliday), 3)
for i in range(len(isWeekend)):
    for k in range(4):
        if isHoliday.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += isHoliday.iloc[i]['emotion_scores'][k]
        if isHoliday.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += isHoliday.iloc[i]['emotion_scores'][k]
        if isHoliday.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += isHoliday.iloc[i]['emotion_scores'][k]
        if isHoliday.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += isHoliday.iloc[i]['emotion_scores'][k]
academicList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(academicList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Holiday Emotion Distribution')
plt.show()

# %%
nonHoliday = data[data['is_holiday'] == False]
emotionsDict = {'Optimism':0, 'Excitement':0,'Concern':0,'Skepticism':0}
random_colors = np.random.rand(len(nonHoliday), 3)
for i in range(len(isWeekend)):
    for k in range(4):
        if nonHoliday.iloc[i]['emotions'][k] == 'Optimism':
            emotionsDict['Optimism'] += nonHoliday.iloc[i]['emotion_scores'][k]
        if nonHoliday.iloc[i]['emotions'][k] == 'Concern':
            emotionsDict['Concern'] += nonHoliday.iloc[i]['emotion_scores'][k]
        if nonHoliday.iloc[i]['emotions'][k] == 'Excitement':
            emotionsDict['Excitement'] += nonHoliday.iloc[i]['emotion_scores'][k]
        if nonHoliday.iloc[i]['emotions'][k] == 'Skepticism':
            emotionsDict['Skepticism'] += nonHoliday.iloc[i]['emotion_scores'][k]
academicList = list(emotionsDict.values())
emotionsList = list(emotionsDict.keys())
plt.pie(academicList, labels=emotionsList, autopct='%1.1f%%', startangle=90, colors=random_colors)
plt.title('Non-Holiday Emotion Distribution')
plt.show()

# %%
language_counts = data['language'].value_counts().reset_index()
languages = language_counts[0:10]
top_languages = language_counts.head(10)
language_map = {
    'en': 'English',
    'ko': 'Korean',
    'ja': 'Japanese',
    'es': 'Spanish',
    'fr': 'French',
    'id': 'Indonesian',
    'de': 'German',
    'vi': 'Vietnamese',
    'pt': 'Portuguese',
    'it': 'Italian'
}

top_languages['language'] = top_languages['language'].replace(language_map)

languages = top_languages['language']
counts = top_languages['count']

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

x_pos = np.arange(len(languages))

width = 0.5
depth = 0.5

for i, (lang, count) in enumerate(zip(languages, counts)):
    ax.bar3d(x_pos[i], 0, 0, width, depth, count, alpha=0.8)
ax.set_xticks(x_pos)
ax.set_xticklabels(languages, rotation=45, ha='right')
ax.set_ylabel('Count')
ax.set_zlabel('Frequency')
ax.set_title('Top 10 Languages by Count')
ax.grid(False)
plt.show()
# Out:
# /var/folders/0c/nyvp3tfn1hbdbcbf9t96kq_h0000gn/T/ipykernel_68620/897655602.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
