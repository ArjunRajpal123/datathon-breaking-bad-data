# %% [markdown]
# # Second Attempt At EDA
#
# The primary focus of this document is to explore the data and understand the data. This is the first step in the data science process. We also used this document to produce some visualizations for this model.

# %%
import gensim
from gensim import corpora
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/arjunrajpal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('./data/clean_titles.csv')
df.head()
# Out:
#                                                title  \
# 0  Kann künstliche Intelligenz Smalltalk ersetzen...
# 1  Lidé se snadněji svěří chatbotům. Emocionální ...
# 2  ¿Cómo implementar la IA en el comercio online?...
# 3  Kontrolle von KI: Vorsicht, KI! | ZEIT ONLINE ...
# 4  Los consejos para ganar la lotería de la Intel...
#
#                                                 link        date  \
# 0  https://news.google.com/rss/articles/CBMiY2h0d...  2023-11-12
# 1  https://news.google.com/rss/articles/CBMidmh0d...  2023-11-12
# 2  https://news.google.com/rss/articles/CBMicmh0d...  2023-11-12
# 3  https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
# 4  https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
#
#                 source country language  \
# 0                Blick      US       de
# 1             iDNES.cz      US       cs
# 2         RRHH Digital      US       es
# 3  ZEIT ONLINE English      US       de
# 4                  C5N      US       es
#
#                                     translated_title  \
# 0  Can artificial intelligence replace small talk...
# 1  People trust chatbots more easily. Emotional A...
# 2  How to implement AI in online commerce? - Digi...
# 3  Controlling AI: Be careful, AI! | ZEIT ONLINE ...
# 4  Tips to win the Artificial Intelligence lotter...
#
#    number_of_characters_title  number_of_words_title day_of_week  ...  \
# 0                          47                      8      Sunday  ...
# 1                          72                     13      Sunday  ...
# 2                          43                     10      Sunday  ...
# 3                          56                     12      Sunday  ...
# 4                          45                      9      Sunday  ...
#
#    source_type                               final_redirected_URL  \
# 0  News Outlet  https://www.blick.ch/schweiz/linguistik-profes...
# 1        Other  https://www.idnes.cz/zpravy/domaci/ai-umela-in...
# 2  News Outlet  https://www.rrhhdigital.com/secciones/tecnolog...
# 3        Other  https://www.zeit.de/zeit-wissen/2023/06/kuenst...
# 4        Other  https://www.c5n.com/sociedad/los-consejos-gana...
#
#          domain_of_URL  subdomain_of_URL  URL_depth top_level_domain  \
# 0         www.blick.ch               www          2               ch
# 1         www.idnes.cz               www          3               cz
# 2  www.rrhhdigital.com               www          5              com
# 3          www.zeit.de               www          4               de
# 4          www.c5n.com               www          2              com
#
#   url_length     author                                      cleaned_title  \
# 0         99         []    Can artificial intelligence replace small talk?
# 1        118  ['Autor']  People trust chatbots more easily. Emotional A...
# 2        114         []            How to implement AI in online commerce?
# 3         93         []      Controlling AI: Be careful, AI! | ZEIT ONLINE
# 4         93         []    Tips to win the Artificial Intelligence lottery
#
#     dominant_topic
# 0   (2, 0.7984908)
# 1  (4, 0.57000524)
# 2  (2, 0.30003065)
# 3  (0, 0.83883363)
# 4  (3, 0.54555273)
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Top 10 languages by Occurence

# %%
# Top 10 Languages by Occurrence

language_counts = df['language'].value_counts()
top_10 = language_counts.head(10)

#Assigning Colors to Top 10 languages 
colors = plt.cm.plasma(np.linspace(0, 1, len(top_10)))
plt.figure(figsize=(10, 6))
top_10.plot(kind='bar', color=colors)

#Generating Plot 
plt.title('Top 10 Languages by Occurrence', fontsize=16)
plt.xlabel('Language', fontsize=12)
plt.ylabel('Count', fontsize=12)
tick_labels = ['English', 'Korean', 'Japanese', 'Spanish', 'French', 'Indonesian', 'German', 'Vietnamese', 'Portuguese', 'Italian']
plt.xticks(range(len(tick_labels)), tick_labels, rotation=45)
plt.subplots_adjust(bottom=0.3)
plt.savefig('top_10_languages.jpg')
plt.tight_layout()
plt.show()

# %%
from matplotlib import colormaps
colors = np.random.rand(len(df['language'].value_counts()), 3)
language_dict = {
    'en': 'English',
    'ko': 'Korean',
    'ja': 'Japanese',
    'es': 'Spanish',
    'fr': 'French',
    'id': 'Indonesian',
    'de': 'German',
    'vi': 'Vietnamese',
    'pt': 'Portuguese',
    'it': 'Italian'
}

# Set the color map to 'Pastel2'
cmap = plt.cm.get_cmap('Pastel2')

df['language'] = df['language'].map(language_dict)
language_counts = df['language'].value_counts()
top_10 = language_counts.head(5)

# Create an array of colors from the colormap
colors = cmap(np.linspace(0,10))
plt.figure(figsize=(10, 6))
plt.pie(top_10, labels=top_10.index, colors=colors, autopct='%1.1f%%')
plt.title('Top 5 Languages by Occurrence', fontsize=16)
plt.savefig('top_10_languages.jpg')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/k1/ypk5p6h57154zss_y_50gngw0000gn/T/ipykernel_70301/1404221115.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Pastel2')

# %% [markdown]
# ## Occurrence of Countries in the Dataset

# %%
country_counts = df['country'].value_counts()
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='green')
plt.title('Occurrence of Countries in the Dataset', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=0) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Occurrence of each Source Type in the Dataset

# %%
source_type = df['source_type'].value_counts()
colors = plt.cm.twilight(np.linspace(0, 1, len(source_type)))
plt.figure(figsize=(10, 6))
source_type.plot(kind='bar', color=colors)
plt.title('Occurrence of each Source Type in the Dataset', fontsize=16)
plt.xlabel('Source Type', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
db = pd.read_csv('./data/Dataset_10k.csv')
db.head()
# Out:
#                                                title  \
# 0  Kann künstliche Intelligenz Smalltalk ersetzen...
# 1  Lidé se snadněji svěří chatbotům. Emocionální ...
# 2  ¿Cómo implementar la IA en el comercio online?...
# 3  Kontrolle von KI: Vorsicht, KI! | ZEIT ONLINE ...
# 4  Los consejos para ganar la lotería de la Intel...
#
#                                                 link        date  \
# 0  https://news.google.com/rss/articles/CBMiY2h0d...  2023-11-12
# 1  https://news.google.com/rss/articles/CBMidmh0d...  2023-11-12
# 2  https://news.google.com/rss/articles/CBMicmh0d...  2023-11-12
# 3  https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
# 4  https://news.google.com/rss/articles/CBMiXWh0d...  2023-11-12
#
#                 source country language  \
# 0                Blick      US       de
# 1             iDNES.cz      US       cs
# 2         RRHH Digital      US       es
# 3  ZEIT ONLINE English      US       de
# 4                  C5N      US       es
#
#                                     translated_title  \
# 0  Can artificial intelligence replace small talk...
# 1  People trust chatbots more easily. Emotional A...
# 2  How to implement AI in online commerce? - Digi...
# 3  Controlling AI: Be careful, AI! | ZEIT ONLINE ...
# 4  Tips to win the Artificial Intelligence lotter...
#
#    number_of_characters_title  number_of_words_title day_of_week  ...  \
# 0                          47                      8      Sunday  ...
# 1                          72                     13      Sunday  ...
# 2                          43                     10      Sunday  ...
# 3                          56                     12      Sunday  ...
# 4                          45                      9      Sunday  ...
#
#    is_weekend  is_holiday  source_type  \
# 0        True       False  News Outlet
# 1        True       False        Other
# 2        True       False  News Outlet
# 3        True       False        Other
# 4        True       False        Other
#
#                                 final_redirected_URL        domain_of_URL  \
# 0  https://www.blick.ch/schweiz/linguistik-profes...         www.blick.ch
# 1  https://www.idnes.cz/zpravy/domaci/ai-umela-in...         www.idnes.cz
# 2  https://www.rrhhdigital.com/secciones/tecnolog...  www.rrhhdigital.com
# 3  https://www.zeit.de/zeit-wissen/2023/06/kuenst...          www.zeit.de
# 4  https://www.c5n.com/sociedad/los-consejos-gana...          www.c5n.com
#
#   subdomain_of_URL URL_depth top_level_domain url_length     author
# 0              www         2               ch         99         []
# 1              www         3               cz        118  ['Autor']
# 2              www         5              com        114         []
# 3              www         4               de         93         []
# 4              www         2              com         93         []
#
# [5 rows x 23 columns]

# %%
weekend_df = db.groupby('is_weekend').size()
holiday_df = db.groupby('is_holiday').size()

# %% [markdown]
# ## Headlines Published on Weekend/Holidays

# %%
plt.figure(figsize=(12, 6))
weekend_df.plot(kind='bar', color=['firebrick', 'forestgreen'])
plt.title('Headlines Published on Weekends')
plt.xlabel('Is Weekend')
plt.ylabel('Count')
plt.xticks([0, 1], labels=['False', 'True'], rotation=0)
plt.savefig('weekend.jpg')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
holiday_df.plot(kind='bar', color=['firebrick', 'forestgreen'])
plt.title('Headlines Published on Holidays')
plt.xlabel('Is Holiday')
plt.ylabel('Count')
plt.xticks([0, 1], labels=['False', 'True'], rotation=0)
plt.savefig('holiday.jpg')
plt.tight_layout()
plt.show()
